# %% [markdown]
# # **Agno**

# %% [markdown]
# ### **Model Call**

# %%
from agno.models.openai import OpenAIChat
from agno.models.message import Message
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

# %%
llm = OpenAIChat(id="gpt-5-mini")

# %%
msg = Message(
    role="user",
    content=[{"type": "text", "text": "What is Python?"}],
)

# %%
response = llm.invoke(
    messages=[msg],
    assistant_message=Message(role="assistant"),
)
print(response.content)
# Out:
# Short answer: Python is a high-level, general-purpose programming language that emphasizes readability and developer productivity.
#
# Key points
# - Designed by Guido van Rossum and first released in 1991.
# - Interpreted and dynamically typed (you don’t declare variable types).
# - Uses indentation to define code blocks, which encourages readable code.
# - Multi-paradigm: supports procedural, object-oriented, and functional programming.
# - Memory-managed (garbage-collected).
# - Open source (Python Software Foundation) with a large standard library and a huge ecosystem of third‑party packages (PyPI).
#
# Why people use it
# - Easy to learn and read — good for beginners.
# - Fast development speed — great for scripting, automation, prototypes.
# - Strong libraries and frameworks for web development (Django, Flask), data science and machine learning (NumPy, pandas, scikit‑learn, TensorFlow, PyTorch), scientific computing, automation, DevOps, and more.
# - Widely used in academia and industry.
#
# Common implementations
# - CPython (the reference implementation, most common).
# - PyPy (JIT-compiled, often faster for long-running programs).
# - Jython (runs on the JVM), IronPython (on .NET).
#
# Versions
# - Python 2 reached end-of-life in 2020. Use Python 3 (latest stable minor version at time of writing is 3.x).
#
# Tiny example
# - Hello world:
#   print("Hello, world!")
# - Simple function and list comprehension:
#   def squares(n): return [i*i for i in range(n)]
#
# How to get started
# - Install from python.org or use Anaconda/Miniconda if you plan to do data science.
# - Learn the basics from the official tutorial (docs.python.org), or books like “Automate the Boring Stuff with Python.”
# - Use pip to install packages and venv/virtualenv or conda environments to manage dependencies.
#
# If you meant the snake instead of the language, tell me and I’ll explain that instead. Would you like a short tutorial, examples for a specific domain (web, data science, automation), or installation help?

# %% [markdown]
# ### **Agent Call**

# %%
from agno.agent import Agent
from agno.tools.tavily import TavilyTools

# %%
agent = Agent(
    model=llm,
    tools=[TavilyTools()],
    debug_mode=True,
)

# %%
response = agent.print_response("""
    Use your tools to answer the following question:
    <question> What is Python? <question />
    """)
# Out:
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃     Use your tools to answer the following question:                         ┃
# ┃     <question> What is Python? <question />                                  ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Tool Calls ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ • web_search_using_tavily(query=What is Python programming language?,        ┃
# ┃ max_results=3)                                                               ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (19.1s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Python is a high-level, interpreted, general-purpose programming language    ┃
# ┃ created by Guido van Rossum and first released in 1991. It emphasizes        ┃
# ┃ readable, concise syntax and supports multiple programming paradigms         ┃
# ┃ (procedural, object-oriented, and functional). The language is maintained by ┃
# ┃ the Python Software Foundation.                                              ┃
# ┃                                                                              ┃
# ┃ Key points                                                                   ┃
# ┃ - Interpreted and dynamically typed: code runs via an interpreter (commonly  ┃
# ┃ CPython) and types are checked at runtime.                                   ┃
# ┃ - Readability and simplicity: clear syntax that’s easy for beginners and     ┃
# ┃ rapid development.                                                           ┃
# ┃ - Batteries-included standard library and a huge ecosystem of third-party    ┃
# ┃ packages (installed with pip).                                               ┃
# ┃ - Common implementations: CPython (reference), PyPy (JIT-compiled), Jython   ┃
# ┃ (for Java), IronPython (for .NET).                                           ┃
# ┃ - License: permissive PSF license.                                           ┃
# ┃                                                                              ┃
# ┃ Typical uses                                                                 ┃
# ┃ - Web development (Django, Flask)                                            ┃
# ┃ - Data science, machine learning, and scientific computing (NumPy, pandas,   ┃
# ┃ scikit-learn, TensorFlow)                                                    ┃
# ┃ - Automation and scripting                                                   ┃
# ┃ - System administration and DevOps                                           ┃
# ┃ - Desktop apps and simple games                                              ┃
# ┃ - Education and prototyping                                                  ┃
# ┃                                                                              ┃
# ┃ Strengths and limitations                                                    ┃
# ┃ - Strengths: fast to write and maintain, large ecosystem, strong community.  ┃
# ┃ - Limitations: generally slower than compiled languages; CPython has a       ┃
# ┃ Global Interpreter Lock (GIL) that limits threaded CPU-bound parallelism;    ┃
# ┃ mobile support and some low-level system tasks are less common.              ┃
# ┃                                                                              ┃
# ┃ Quick example                                                                ┃
# ┃ print("Hello, world!")                                                       ┃
# ┃                                                                              ┃
# ┃ Where to get it                                                              ┃
# ┃ - Official site: https://python.org — installers, docs, and beginner         ┃
# ┃ tutorials.                                                                   ┃
# ┃                                                                              ┃
# ┃ If you want, I can show a short example, suggest learning resources, or help ┃
# ┃ you install Python on your system. Which would you like?                     ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
